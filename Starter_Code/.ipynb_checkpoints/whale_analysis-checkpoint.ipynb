# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_data = Path("../Starter_Code/Resources/whale_returns.csv")
whale_df = pd.read_csv(whale_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
whale_df.head()
# Out:
# /var/folders/l6/y384x_5543jb99ssghwm02dm0000gn/T/ipykernel_3669/3859690244.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   whale_df = pd.read_csv(whale_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# ...

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df = whale_df.dropna()

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_data = Path("../Starter_Code/Resources/algo_returns.csv")
algo_df = pd.read_csv(algo_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
algo_df.head()
# Out:
# /var/folders/l6/y384x_5543jb99ssghwm02dm0000gn/T/ipykernel_3669/189222191.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   algo_df = pd.read_csv(algo_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_df = algo_df.dropna()

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_data = Path("../Starter_Code/Resources/sp500_history.csv")
sp500_df = pd.read_csv(sp500_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
sp500_df.head()
# Out:
# /var/folders/l6/y384x_5543jb99ssghwm02dm0000gn/T/ipykernel_3669/1790153877.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   sp500_df = pd.read_csv(sp500_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
# /var/folders/l6/y384x_5543jb99ssghwm02dm0000gn/T/ipykernel_3669/1790153877.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sp500_df = pd.read_csv(sp500_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
# Check Data Types
sp500_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_df["Close"]= sp500_df["Close"].str.replace('$','').astype("float")
sp500_df
# Out:
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06
# ...             ...
# 2012-10-05  1460.93
# 2012-10-04  1461.40
# 2012-10-03  1450.99
# 2012-10-02  1445.75
# 2012-10-01  1444.49
#
# [1649 rows x 1 columns]

# %%
# Calculate Daily Returns
sp500_daily_returns = sp500_df.pct_change()

# %%
# Drop nulls
sp500_daily_returns.dropna()
sp500_daily_returns.head()
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_daily_returns.rename(columns= {"Close":"SP500"}, inplace=True)

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
all_df = pd.concat([whale_df, algo_df, sp500_daily_returns], axis="columns", join="inner")
all_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
all_df.plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cum_all = (1+ all_df).cumprod()
# Plot cumulative returns
cum_all.plot(figsize = (20,10))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
all_df.plot(kind= "box", figsize=(20,10))
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
daily_std = all_df.std()
daily_std.sort_values()
# Out:
# PAULSON & CO.INC.              0.007023
# Algo 1                         0.007620
# SOROS FUND MANAGEMENT LLC      0.007895
# Algo 2                         0.008342
# SP500                          0.008587
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
sp500 = all_df["SP500"].std()
# Determine which portfolios are riskier than the S&P 500
sp500 < all_df.std()
# Out:
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# SP500                          False
# dtype: bool

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = daily_std * np.sqrt(252)
annualized_std.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
annualized_std.rolling(window=21).std()
# Plot the rolling standard deviation
annualized_std.plot(figsize = (20,10), title = "21 Rolling Standard deviation")
# Out:
# <Axes: title={'center': '21 Rolling Standard deviation'}>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation = all_df.corr()
correlation
# Display de correlation matrix
import seaborn as sns
sns.heatmap(correlation, vmin=-1, vmax=1)
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
covariance = all_df['BERKSHIRE HATHAWAY INC'].cov(all_df['SP500'])
# Calculate variance of S&P 500
variance = all_df['SP500'].var()
# Computing beta
beta = covariance / variance
# Plot beta trend
sns.lmplot(x="SP500", y="BERKSHIRE HATHAWAY INC", data=all_df, aspect=1.5, fit_reg=True)
# Out:
# /Users/victorandujar/anaconda3/envs/dev/lib/python3.11/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
annualized_std.ewm(halflife=21).mean()
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.118297
# TIGER GLOBAL MANAGEMENT LLC    0.137115
# BERKSHIRE HATHAWAY INC         0.154955
# Algo 1                         0.147702
# Algo 2                         0.144942
# SP500                          0.143584
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = all_df.mean() * 252 / (all_df.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# SP500                         -0.518582
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind = "bar", title = "Sharpe Ratios")
# Out:
# <Axes: title={'center': 'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Looks like Algo 1 outperformed both the S&P 500 and the whales portfolios.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
apple_data = Path("../Starter_Code/Resources/aapl_historical.csv")
apple_df = pd.read_csv(apple_data, index_col="Trade DATE", parse_dates=True, infer_datetime_format=True)
apple_df =apple_df.rename(columns={"NOCP":"Apple"})
apple_df.head()
# Out:
# /var/folders/l6/y384x_5543jb99ssghwm02dm0000gn/T/ipykernel_3669/716118814.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   apple_df = pd.read_csv(apple_data, index_col="Trade DATE", parse_dates=True, infer_datetime_format=True)
#            Symbol   Apple
# Trade DATE
# 2019-05-09   AAPL  200.72
# 2019-05-08   AAPL  202.90
# 2019-05-07   AAPL  202.86
# 2019-05-06   AAPL  208.48
# 2019-05-03   AAPL  211.75

# %%
# Reading data from 2nd stock
google_data = Path("../Starter_code/Resources/goog_historical.csv")
google_df = pd.read_csv(google_data, index_col="Trade DATE", parse_dates=True, infer_datetime_format=True)
google_df = google_df.rename(columns={"NOCP":"Google"})
google_df.head()
# Out:
# /var/folders/l6/y384x_5543jb99ssghwm02dm0000gn/T/ipykernel_3669/3186561478.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   google_df = pd.read_csv(google_data, index_col="Trade DATE", parse_dates=True, infer_datetime_format=True)
#            Symbol   Google
# Trade DATE
# 2019-05-09   GOOG  1162.38
# 2019-05-08   GOOG  1166.27
# 2019-05-07   GOOG  1174.10
# 2019-05-06   GOOG  1189.39
# 2019-05-03   GOOG  1185.40

# %%
# Reading data from 3rd stock
costco_data = Path("../Starter_Code/Resources/cost_historical.csv")
costco_df = pd.read_csv(costco_data, index_col="Trade DATE", parse_dates=True, infer_datetime_format=True)
costco_df = costco_df.rename(columns={"NOCP":"Costco"})
costco_df.head()
# Out:
# /var/folders/l6/y384x_5543jb99ssghwm02dm0000gn/T/ipykernel_3669/3278545583.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   costco_df = pd.read_csv(costco_data, index_col="Trade DATE", parse_dates=True, infer_datetime_format=True)
#            Symbol  Costco
# Trade DATE
# 2019-05-09   COST  243.47
# 2019-05-08   COST  241.34
# 2019-05-07   COST  240.18
# 2019-05-06   COST  244.23
# 2019-05-03   COST  244.62

# %%
# Combine all stocks in a single DataFrame
combined_df = pd.concat([apple_df, google_df, costco_df], axis="columns", join="inner")
combined_df
# Out:
#            Symbol   Apple Symbol   Google Symbol  Costco
# Trade DATE
# 2019-05-09   AAPL  200.72   GOOG  1162.38   COST  243.47
# 2019-05-08   AAPL  202.90   GOOG  1166.27   COST  241.34
# 2019-05-07   AAPL  202.86   GOOG  1174.10   COST  240.18
# 2019-05-06   AAPL  208.48   GOOG  1189.39   COST  244.23
# 2019-05-03   AAPL  211.75   GOOG  1185.40   COST  244.62
# ...           ...     ...    ...      ...    ...     ...
# 2018-05-17   AAPL  186.99   GOOG  1078.59   COST  199.60
# 2018-05-16   AAPL  188.18   GOOG  1081.77   COST  198.71
# 2018-05-15   AAPL  186.44   GOOG  1079.23   COST  195.48
# 2018-05-14   AAPL  188.15   GOOG  1100.20   COST  195.88
# 2018-05-11   AAPL  188.59   GOOG  1098.26   COST  195.76
#
# [250 rows x 6 columns]

# %%
# Reset Date index
combined_df.index = combined_df.index.normalize()

# %%
combined_df = combined_df.drop(columns=["Symbol"])
combined_df
# Out:
#              Apple   Google  Costco
# Trade DATE
# 2019-05-09  200.72  1162.38  243.47
# 2019-05-08  202.90  1166.27  241.34
# 2019-05-07  202.86  1174.10  240.18
# 2019-05-06  208.48  1189.39  244.23
# 2019-05-03  211.75  1185.40  244.62
# ...            ...      ...     ...
# 2018-05-17  186.99  1078.59  199.60
# 2018-05-16  188.18  1081.77  198.71
# 2018-05-15  186.44  1079.23  195.48
# 2018-05-14  188.15  1100.20  195.88
# 2018-05-11  188.59  1098.26  195.76
#
# [250 rows x 3 columns]

# %%
# Calculate daily returns = 
combined_daily_returns = combined_df.pct_change()
combined_daily_returns
# Drop NAs
combined_daily_returns = combined_daily_returns.dropna()
combined_daily_returns.isnull().sum
# Display sample data
combined_daily_returns.sample()
# Out:
#                Apple    Google    Costco
# Trade DATE
# 2018-08-21 -0.000047 -0.004729 -0.002923

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
combined_daily_returns = combined_daily_returns.dot(weights)
# Display sample data
combined_daily_returns
# Out:
# Trade DATE
# 2019-05-08    0.001820
# 2019-05-07    0.000570
# 2019-05-06    0.019196
# 2019-05-03    0.004642
# 2019-05-02   -0.013131
#                 ...
# 2018-05-17    0.006112
# 2018-05-16    0.001618
# 2018-05-15   -0.009283
# 2018-05-14    0.010216
# 2018-05-11   -0.000012
# Length: 249, dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
all_portfolios = pd.concat([combined_daily_returns, all_df], axis="columns", join="inner")
all_portfolios = all_portfolios.rename(columns={0 : "My Portfolio"})
all_portfolios
# Out:
#             My Portfolio  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2019-04-23     -0.000415                   0.007167            0.003485
# 2019-04-22     -0.011812                  -0.002586           -0.007333
# 2019-04-18     -0.001148                   0.001448            0.001222
# 2019-04-17     -0.001541                  -0.002897           -0.006467
# 2019-04-16     -0.009149                   0.002699            0.000388
# ...                  ...                        ...                 ...
# 2018-05-17      0.006112                  -0.001955            0.002524
# 2018-05-16      0.001618                   0.008637            0.006244
# 2018-05-15     -0.009283                  -0.000726           -0.001409
# 2018-05-14      0.010216                   0.000000            0.000000
# 2018-05-11     -0.000012                  -0.004717            0.000982
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
all_portfolios = all_portfolios.dropna()
all_portfolios.isnull().sum()
# Out:
# My Portfolio                   0
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# Algo 1                         0
# Algo 2                         0
# SP500                          0
# dtype: int64

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
all_portfolios_std = all_portfolios * np.sqrt(252)
all_portfolios_std.head()
# Out:
#             My Portfolio  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2019-04-22     -0.187516                  -0.041047           -0.116402
# 2019-04-18     -0.018217                   0.022985            0.019396
# 2019-04-17     -0.024458                  -0.045984           -0.102663
# 2019-04-16     -0.145233                   0.042852            0.006162
# 2019-04-15     -0.005181                  -0.022573           -0.018356
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2019-04-22                    -0.057787               -0.017268  0.010740
# 2019-04-18                     0.009232                0.030417 -0.009333
# 2019-04-17                    -0.069998                0.051150 -0.163524
# 2019-04-16                    -0.013191                0.013282 -0.110244
# 2019-04-15                     0.006317               -0.166561 -0.068757
#
#               Algo 2     SP500
# 2019-04-22 -0.030728 -0.139120
# ...

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
all_portfolios_std.rolling(window=21).std().dropna()
# Plot rolling standard deviation
all_portfolios_std.plot(figsize=(10,5), title="Rolling Standard Deviation")
# Out:
# <Axes: title={'center': 'Rolling Standard Deviation'}>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
correlation = all_portfolios.corr()
sns.heatmap(correlation, vmin=-1, vmax=1)
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
covariance = all_portfolios['My Portfolio'].cov(all_portfolios['SP500'])
variance = all_portfolios['SP500'].var()
beta = covariance / variance
sns.lmplot(x='SP500', y='My Portfolio', data=all_portfolios)
# Out:
# /Users/victorandujar/anaconda3/envs/dev/lib/python3.11/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
portfolios_sharpe_ratio = all_portfolios.std() * np.sqrt(252)
portfolios_sharpe_ratio
# Out:
# My Portfolio                   0.213137
# SOROS FUND MANAGEMENT LLC      0.146589
# PAULSON & CO.INC.              0.116683
# TIGER GLOBAL MANAGEMENT LLC    0.232434
# BERKSHIRE HATHAWAY INC         0.246819
# Algo 1                         0.133645
# Algo 2                         0.139204
# SP500                          0.152147
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
portfolios_sharpe_ratio.plot(kind = 'bar', title = "sharpe ratios")
# Out:
# <Axes: title={'center': 'sharpe ratios'}>

# %% [markdown]
# ### How does your portfolio do?
#
# My portfolio is outperforming the SP500 but trails Tiger Global Management LLC and Berkshire Hathaway Inc by a small margin.
